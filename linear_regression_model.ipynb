# %%
from sklearn import linear_model
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import re
# %matplotlib inline

# %%
#FBI dataset

path = "/Users/elijahwoolford/Desktop/python /table_8_offenses_known_to_law_enforcement_new_york_by_city_2013.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                              Table 8  Unnamed: 1      Unnamed: 2  \
# 0                           NEW YORK         NaN             NaN
# 1  Offenses Known to Law Enforcement         NaN             NaN
# 2                      by City, 2013         NaN             NaN
# 3                               City  Population  Violent\rcrime
# 4                      Adams Village       1,861               0
#
#                                Unnamed: 3                    Unnamed: 4  \
# 0                                     NaN                           NaN
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
# 3  Murder and\rnonnegligent\rmanslaughter  Rape\r(revised\rdefinition)1
# 4                                       0                           NaN
#
#                     Unnamed: 5 Unnamed: 6           Unnamed: 7  \
# 0                          NaN        NaN                  NaN
# 1                                     NaN                  NaN
# 2                          NaN        NaN                  NaN
# 3  Rape\r(legacy\rdefinition)2    Robbery  Aggravated\rassault
# 4                            0          0                    0
#
#         Unnamed: 8 Unnamed: 9      Unnamed: 10            Unnamed: 11  \
# 0              NaN        NaN              NaN                    NaN
# 1              NaN        NaN              NaN                    NaN
# 2              NaN        NaN              NaN                    NaN
# 3  Property\rcrime   Burglary  Larceny-\rtheft  Motor\rvehicle\rtheft
# 4               12          2               10                      0
#
#   Unnamed: 12  Unnamed: 13
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN          NaN
# 3      Arson3          NaN
# 4           0          NaN

# %%
#Clean up time

df = df.drop(df.index[0:4])
df = df.drop(df.index[-3:])
df = df.rename(index=str, columns={"Table 8": "City","Unnamed: 1": "Population", "Unnamed: 2": "Violent Crime", 
                                   "Unnamed: 3": "Murder", "Unnamed: 5": "Rape", "Unnamed: 6": "Robbery", 
                                   "Unnamed: 7": "Aggravated Assault", "Unnamed: 8": "Property Crime", 
                                   "Unnamed: 9": "Burglary", "Unnamed: 10": "Larceny-Theft", "Unnamed: 11": "Motor Vehicle Theft", 
                                   "Unnamed: 12": "Arson"})
df = df.drop(columns=["Unnamed: 4", "Unnamed: 13"])
df.head()
# Out:
#                        City Population Violent Crime Murder Rape Robbery  \
# 4             Adams Village      1,861             0      0    0       0
# 5  Addison Town and Village      2,577             3      0    0       0
# 6             Akron Village      2,846             3      0    0       0
# 7                    Albany     97,956           791      8   30     227
# 8            Albion Village      6,388            23      0    3       4
#
#   Aggravated Assault Property Crime Burglary Larceny-Theft  \
# 4                  0             12        2            10
# 5                  3             24        3            20
# 6                  3             16        1            15
# 7                526          4,090      705         3,243
# 8                 16            223       53           165
#
#   Motor Vehicle Theft Arson
# 4                   0     0
# 5                   1     0
# 6                   0     0
# 7                 142   NaN
# 8                   5   NaN

# %%
#Create new dataframe for modeling

df_model = pd.DataFrame()
#df_model["City"] = df["City"]
df_model["Population"] = df["Population"].apply(lambda x: re.sub(",", "", x)).astype(int)
df_model["Population_squared"] = df_model["Population"]**2
df_model["Murder"] = df["Murder"].apply(lambda x: 0 if int(x) == 0  else 1)
df_model["Robbery"] = df["Robbery"].apply(lambda x: 0 if x == "0" else 1)
df_model.head()
# Out:
#    Population  Population_squared  Murder  Robbery
# 4        1861             3463321       0        0
# 5        2577             6640929       0        0
# 6        2846             8099716       0        0
# 7       97956          9595377936       1        1
# 8        6388            40806544       0        1

# %%
#Dependent Variable 

df_outcome = pd.DataFrame()
df_outcome["Property Crime"] = df["Property Crime"].apply(lambda x: re.sub(",", "", x)).astype(int)
df_outcome.head()
# Out:
#    Property Crime
# 4              12
# 5              24
# 6              16
# 7            4090
# 8             223

# %%
reg = linear_model.LinearRegression()
reg.fit(df_model,df_outcome)
print("Coefficients: \n", reg.coef_)
print("Intercept: \n", reg.intercept_)
# Out:
# Coefficients:
#  [[ 3.46570268e-02 -2.11108019e-09  1.51866535e+01 -9.62774363e+01]]
# Intercept:
#  [-109.57533562]
